# %%
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("GPU devices:", tf.config.list_physical_devices("GPU"))
# Out:
# TensorFlow version: 2.20.0
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# --- Dataset ---
img_size = (224, 224)
batch_size = 32
seed = 123

train_ds = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    validation_split=0.2,
    subset="training",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "datasets",
    validation_split=0.2,
    subset="validation",
    seed=seed,
    image_size=img_size,
    batch_size=batch_size
)

class_names = train_ds.class_names
print("Kelas:", class_names)

# --- Optimasi pipeline (prefetch) ---
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# --- Augmentasi ---
data_augmentation = keras.Sequential([
    layers.RandomFlip("horizontal"),
    layers.RandomRotation(0.2),
    layers.RandomZoom(0.2),
    layers.RandomContrast(0.2),
])

# --- Base Model Transfer Learning ---
base_model = tf.keras.applications.MobileNetV2(
    input_shape=img_size + (3,),
    include_top=False,
    weights="imagenet"
)
base_model.trainable = False  # freeze dulu

# --- Model ---
model = keras.Sequential([
    data_augmentation,
    layers.Rescaling(1./255),
    base_model,
    layers.GlobalAveragePooling2D(),
    layers.Dropout(0.3),
    layers.Dense(len(class_names), activation="softmax")
])

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0001),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

# --- Training ---
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=10
)

# --- Evaluasi ---
loss, acc = model.evaluate(val_ds)
print(f"\n✅ Akurasi validasi: {acc:.2f}")

# --- Simpan model ---
model.save("bicara_mobilenetv2.h5")
# Out:
# Found 4000 files belonging to 4 classes.
# Using 3200 files for training.
# Found 4000 files belonging to 4 classes.
# Using 800 files for validation.
# Kelas: ['C', 'I', 'L', 'V']
# Epoch 1/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 93ms/step - accuracy: 0.4581 - loss: 1.2394 - val_accuracy: 0.8800 - val_loss: 0.6143
# Epoch 2/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.7816 - loss: 0.6310 - val_accuracy: 0.9850 - val_loss: 0.3169
# Epoch 3/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 82ms/step - accuracy: 0.9028 - loss: 0.3722 - val_accuracy: 0.9962 - val_loss: 0.1938
# Epoch 4/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9531 - loss: 0.2543 - val_accuracy: 0.9975 - val_loss: 0.1251
# Epoch 5/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9719 - loss: 0.1865 - val_accuracy: 0.9975 - val_loss: 0.0913
# Epoch 6/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9819 - loss: 0.1460 - val_accuracy: 0.9975 - val_loss: 0.0696
# Epoch 7/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9891 - loss: 0.1105 - val_accuracy: 0.9975 - val_loss: 0.0535
# Epoch 8/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9912 - loss: 0.0934 - val_accuracy: 0.9975 - val_loss: 0.0444
# Epoch 9/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 84ms/step - accuracy: 0.9947 - loss: 0.0763 - val_accuracy: 0.9975 - val_loss: 0.0391
# Epoch 10/10
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9947 - loss: 0.0671 - val_accuracy: 0.9975 - val_loss: 0.0331
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 2s 63ms/step - accuracy: 0.9975 - loss: 0.0331
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# ✅ Akurasi validasi: 1.00

# %%
# 1. Import library
import tensorflow as tf
from tensorflow import keras
import numpy as np
import pathlib
from tensorflow.keras.preprocessing import image

# 2. Path dataset dan model
dataset_dir = pathlib.Path('/home/antariksa/Desktop/Coding/bicara-model/datasets')
model_path = "bicara_mobilenetv2.h5"

# 3. Load model yang sudah dilatih
model = keras.models.load_model(model_path)
print("✅ Model berhasil dimuat!")

# 4. Ambil nama kelas dari folder dataset (sama dengan saat training)
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=(224, 224),
    batch_size=32
)

class_names = train_ds.class_names
print("Kelas yang ditemukan:", class_names)

def predict_image(img_path):
    # Load gambar
    img = image.load_img(img_path, target_size=(224, 224))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)  # JANGAN dibagi 255 (sudah ada Rescaling di model)

    # Prediksi (pastikan dropout nonaktif)
    predictions = model(img_array, training=False).numpy()
    score = tf.nn.softmax(predictions[0])

    predicted_class = class_names[np.argmax(score)]
    confidence = 100 * np.max(score)

    print(f"Gambar: {img_path}")
    print(f"Prediksi: {predicted_class} ({confidence:.2f}% confidence)")

    return predicted_class, confidence


# 6. Contoh penggunaan
img_path = "/home/antariksa/Desktop/Coding/bicara-model/datasets/V/Image_900.jpg"  # ganti sesuai gambar
predict_image(img_path)
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.
# ✅ Model berhasil dimuat!
# Found 4000 files belonging to 4 classes.
# Using 3200 files for training.
# Kelas yang ditemukan: ['C', 'I', 'L', 'V']
# Gambar: /home/antariksa/Desktop/Coding/bicara-model/datasets/V/Image_900.jpg
# Prediksi: V (43.88% confidence)
# ('V', 43.879154324531555)

# %%
import cv2
import time
import os
import numpy as np
import math
from cvzone.HandTrackingModule import HandDetector

# --- SETUP ---
cap = cv2.VideoCapture(0)
detector = HandDetector(maxHands=2, detectionCon=0.7, minTrackCon=0.5)

offset = 25
imgSize = 300
folder = "datasets/B"
os.makedirs(folder, exist_ok=True)

# Variabel untuk cek stabil
stable_start_time = None
last_bbox = None
capture_delay = 2  # detik (Waktu tunggu awal sebelum mulai mengambil gambar)
max_images = 1000

# === LOGIKA BARU UNTUK PENGAMBILAN CEPAT ===
# Variabel untuk mengatur jeda antar pengambilan gambar setelah stabil
last_capture_time = 0
capture_interval = 0.1 # Ambil gambar setiap 0.1 detik jika tangan tetap stabil

# Definisi koneksi antar landmark jari (MediaPipe Hands style)
connections = [
    (0,1),(1,2),(2,3),(3,4),        # jempol
    (0,5),(5,6),(6,7),(7,8),        # telunjuk
    (5,9),(9,10),(10,11),(11,12),   # tengah
    (9,13),(13,14),(14,15),(15,16), # manis
    (13,17),(17,18),(18,19),(19,20),# kelingking
    (0,17)                          # telapak bawah
]

while True:
    success, img = cap.read()
    if not success:
        break

    img = cv2.flip(img, 1)
    hands, _ = detector.findHands(img, draw=False, flipType=False)

    if len(hands) == 2:
        # Ambil bounding box gabungan dari 2 tangan
        x1, y1, w1, h1 = hands[0]['bbox']
        x2, y2, w2, h2 = hands[1]['bbox']

        x_min = max(0, min(x1, x2) - offset)
        y_min = max(0, min(y1, y2) - offset)
        x_max = min(img.shape[1], max(x1 + w1, x2 + w2) + offset)
        y_max = min(img.shape[0], max(y1 + h1, y2 + h2) + offset)

        imgCrop = img[y_min:y_max, x_min:x_max].copy()

        if imgCrop.shape[0] > 0 and imgCrop.shape[1] > 0:
            # Gambar landmark di atas imgCrop
            for hand_data in hands:
                lmList = hand_data['lmList']

                # Titik merah
                for lx, ly, _ in lmList:
                    lx_crop, ly_crop = lx - x_min, ly - y_min
                    cv2.circle(imgCrop, (lx_crop, ly_crop), 5, (0, 0, 255), cv2.FILLED)

                # Garis putih
                for start, end in connections:
                    x1_lm, y1_lm, _ = lmList[start]
                    x2_lm, y2_lm, _ = lmList[end]
                    cv2.line(imgCrop, (x1_lm - x_min, y1_lm - y_min),
                                      (x2_lm - x_min, y2_lm - y_min), (255, 255, 255), 2)

            # === CEK STABILITAS DAN SIMPAN ===
            current_bbox = (x_min, y_min, x_max, y_max)
            if last_bbox is not None:
                diff = np.abs(np.array(current_bbox) - np.array(last_bbox)).sum()
                if diff < 30:  # artinya tangan relatif stabil
                    if stable_start_time is None:
                        stable_start_time = time.time()
                    else:
                        elapsed = time.time() - stable_start_time
                        cv2.putText(img, f"Stabil {elapsed:.1f}s", (50, 50),
                                    cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

                        # Tunggu hingga delay awal terpenuhi, lalu mulai pengambilan gambar cepat
                        if elapsed >= capture_delay:
                            
                            # === LOGIKA BARU DITERAPKAN DI SINI ===
                            # Cek apakah sudah waktunya mengambil gambar lagi berdasarkan interval
                            current_time = time.time()
                            if current_time - last_capture_time > capture_interval:
                                last_capture_time = current_time # Update waktu pengambilan terakhir
                                
                                count = len(os.listdir(folder))
                                if count >= max_images:
                                    print(f"Sudah mencapai batas maksimal gambar ({max_images}).")
                                    break

                                if imgCrop.size > 0:
                                    imgWhite = np.ones((imgSize, imgSize, 3), np.uint8) * 255
                                    h_crop, w_crop, _ = imgCrop.shape
                                    aspectRatio = h_crop / w_crop
                                    if aspectRatio > 1:
                                        k = imgSize / h_crop
                                        wCal = math.ceil(k * w_crop)
                                        imgResize = cv2.resize(imgCrop, (wCal, imgSize))
                                        wGap = math.ceil((imgSize - wCal) / 2)
                                        imgWhite[:, wGap:wCal + wGap] = imgResize
                                    else:
                                        k = imgSize / w_crop
                                        hCal = math.ceil(k * h_crop)
                                        imgResize = cv2.resize(imgCrop, (imgSize, hCal))
                                        hGap = math.ceil((imgSize - hCal) / 2)
                                        imgWhite[hGap:hCal + hGap, :] = imgResize

                                    save_path = f"{folder}/Image_{count + 1}.jpg"
                                    cv2.imwrite(save_path, imgWhite)
                                    # Tambahkan print untuk melihat progres
                                    print(f"Gambar disimpan: {save_path} ({count + 1}/{max_images})")
                                    # stable_start_time TIDAK di-reset agar pengambilan berlanjut
                else:
                    # Reset timer jika tangan bergerak
                    stable_start_time = None
            last_bbox = current_bbox

            cv2.imshow("Gestur BISINDO (2 Tangan)", imgCrop)

    else:
        # Reset timer jika tangan tidak terdeteksi
        stable_start_time = None

    cv2.imshow("Image", img)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# I0000 00:00:1757736747.213396   95859 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1757736747.215667  142006 gl_context.cc:344] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.0.7-0ubuntu0.24.04.2), renderer: AMD Radeon Graphics (radeonsi, renoir, ACO, DRM 3.61, 6.14.0-29-generic)
# Gambar disimpan: datasets/B/Image_1.jpg (1/1000)
# Gambar disimpan: datasets/B/Image_2.jpg (2/1000)
# Gambar disimpan: datasets/B/Image_3.jpg (3/1000)
# Gambar disimpan: datasets/B/Image_4.jpg (4/1000)
# Gambar disimpan: datasets/B/Image_5.jpg (5/1000)
# Gambar disimpan: datasets/B/Image_6.jpg (6/1000)
# Gambar disimpan: datasets/B/Image_7.jpg (7/1000)
# Gambar disimpan: datasets/B/Image_8.jpg (8/1000)
# Gambar disimpan: datasets/B/Image_9.jpg (9/1000)
# Gambar disimpan: datasets/B/Image_10.jpg (10/1000)
# Gambar disimpan: datasets/B/Image_11.jpg (11/1000)
# Gambar disimpan: datasets/B/Image_12.jpg (12/1000)
# Gambar disimpan: datasets/B/Image_13.jpg (13/1000)
# Gambar disimpan: datasets/B/Image_14.jpg (14/1000)
# Gambar disimpan: datasets/B/Image_15.jpg (15/1000)
# Gambar disimpan: datasets/B/Image_16.jpg (16/1000)
# Gambar disimpan: datasets/B/Image_17.jpg (17/1000)
# Gambar disimpan: datasets/B/Image_18.jpg (18/1000)
# Gambar disimpan: datasets/B/Image_19.jpg (19/1000)
# Gambar disimpan: datasets/B/Image_20.jpg (20/1000)
# Gambar disimpan: datasets/B/Image_21.jpg (21/1000)
# Gambar disimpan: datasets/B/Image_22.jpg (22/1000)
# Gambar disimpan: datasets/B/Image_23.jpg (23/1000)
# Gambar disimpan: datasets/B/Image_24.jpg (24/1000)
# Gambar disimpan: datasets/B/Image_25.jpg (25/1000)
# Gambar disimpan: datasets/B/Image_26.jpg (26/1000)
# Gambar disimpan: datasets/B/Image_27.jpg (27/1000)
# Gambar disimpan: datasets/B/Image_28.jpg (28/1000)
# Gambar disimpan: datasets/B/Image_29.jpg (29/1000)
# Gambar disimpan: datasets/B/Image_30.jpg (30/1000)
# Gambar disimpan: datasets/B/Image_31.jpg (31/1000)
# Gambar disimpan: datasets/B/Image_32.jpg (32/1000)
# Gambar disimpan: datasets/B/Image_33.jpg (33/1000)
# Gambar disimpan: datasets/B/Image_34.jpg (34/1000)
# Gambar disimpan: datasets/B/Image_35.jpg (35/1000)
# Gambar disimpan: datasets/B/Image_36.jpg (36/1000)
# Gambar disimpan: datasets/B/Image_37.jpg (37/1000)
# Gambar disimpan: datasets/B/Image_38.jpg (38/1000)
# Gambar disimpan: datasets/B/Image_39.jpg (39/1000)
# Gambar disimpan: datasets/B/Image_40.jpg (40/1000)
# Gambar disimpan: datasets/B/Image_41.jpg (41/1000)
# Gambar disimpan: datasets/B/Image_42.jpg (42/1000)
# Gambar disimpan: datasets/B/Image_43.jpg (43/1000)
# Gambar disimpan: datasets/B/Image_44.jpg (44/1000)
# Gambar disimpan: datasets/B/Image_45.jpg (45/1000)
# Gambar disimpan: datasets/B/Image_46.jpg (46/1000)
# Gambar disimpan: datasets/B/Image_47.jpg (47/1000)
# Gambar disimpan: datasets/B/Image_48.jpg (48/1000)
# Gambar disimpan: datasets/B/Image_49.jpg (49/1000)
# Gambar disimpan: datasets/B/Image_50.jpg (50/1000)
# Gambar disimpan: datasets/B/Image_51.jpg (51/1000)
# Gambar disimpan: datasets/B/Image_52.jpg (52/1000)
# Gambar disimpan: datasets/B/Image_53.jpg (53/1000)
# Gambar disimpan: datasets/B/Image_54.jpg (54/1000)
# Gambar disimpan: datasets/B/Image_55.jpg (55/1000)
# Gambar disimpan: datasets/B/Image_56.jpg (56/1000)
# Gambar disimpan: datasets/B/Image_57.jpg (57/1000)
# Gambar disimpan: datasets/B/Image_58.jpg (58/1000)
# Gambar disimpan: datasets/B/Image_59.jpg (59/1000)
# Gambar disimpan: datasets/B/Image_60.jpg (60/1000)
# Gambar disimpan: datasets/B/Image_61.jpg (61/1000)
# Gambar disimpan: datasets/B/Image_62.jpg (62/1000)
# Gambar disimpan: datasets/B/Image_63.jpg (63/1000)
# Gambar disimpan: datasets/B/Image_64.jpg (64/1000)
# Gambar disimpan: datasets/B/Image_65.jpg (65/1000)
# Gambar disimpan: datasets/B/Image_66.jpg (66/1000)
# Gambar disimpan: datasets/B/Image_67.jpg (67/1000)
# Gambar disimpan: datasets/B/Image_68.jpg (68/1000)
# Gambar disimpan: datasets/B/Image_69.jpg (69/1000)
# Gambar disimpan: datasets/B/Image_70.jpg (70/1000)
# Gambar disimpan: datasets/B/Image_71.jpg (71/1000)
# Gambar disimpan: datasets/B/Image_72.jpg (72/1000)
# Gambar disimpan: datasets/B/Image_73.jpg (73/1000)
# Gambar disimpan: datasets/B/Image_74.jpg (74/1000)
# Gambar disimpan: datasets/B/Image_75.jpg (75/1000)
# Gambar disimpan: datasets/B/Image_76.jpg (76/1000)
# Gambar disimpan: datasets/B/Image_77.jpg (77/1000)
# Gambar disimpan: datasets/B/Image_78.jpg (78/1000)
# Gambar disimpan: datasets/B/Image_79.jpg (79/1000)
# Gambar disimpan: datasets/B/Image_80.jpg (80/1000)
# Gambar disimpan: datasets/B/Image_81.jpg (81/1000)
# Gambar disimpan: datasets/B/Image_82.jpg (82/1000)
# Gambar disimpan: datasets/B/Image_83.jpg (83/1000)
# Gambar disimpan: datasets/B/Image_84.jpg (84/1000)
# Gambar disimpan: datasets/B/Image_85.jpg (85/1000)
# Gambar disimpan: datasets/B/Image_86.jpg (86/1000)
# Gambar disimpan: datasets/B/Image_87.jpg (87/1000)
# Gambar disimpan: datasets/B/Image_88.jpg (88/1000)
# Gambar disimpan: datasets/B/Image_89.jpg (89/1000)
# Gambar disimpan: datasets/B/Image_90.jpg (90/1000)
# Gambar disimpan: datasets/B/Image_91.jpg (91/1000)
# Gambar disimpan: datasets/B/Image_92.jpg (92/1000)
# Gambar disimpan: datasets/B/Image_93.jpg (93/1000)
# Gambar disimpan: datasets/B/Image_94.jpg (94/1000)
# Gambar disimpan: datasets/B/Image_95.jpg (95/1000)
# Gambar disimpan: datasets/B/Image_96.jpg (96/1000)
# Gambar disimpan: datasets/B/Image_97.jpg (97/1000)
# Gambar disimpan: datasets/B/Image_98.jpg (98/1000)
# Gambar disimpan: datasets/B/Image_99.jpg (99/1000)
# Gambar disimpan: datasets/B/Image_100.jpg (100/1000)
# Gambar disimpan: datasets/B/Image_101.jpg (101/1000)
# Gambar disimpan: datasets/B/Image_102.jpg (102/1000)
# Gambar disimpan: datasets/B/Image_103.jpg (103/1000)
# Gambar disimpan: datasets/B/Image_104.jpg (104/1000)
# Gambar disimpan: datasets/B/Image_105.jpg (105/1000)
# Gambar disimpan: datasets/B/Image_106.jpg (106/1000)
# Gambar disimpan: datasets/B/Image_107.jpg (107/1000)
# Gambar disimpan: datasets/B/Image_108.jpg (108/1000)
# Gambar disimpan: datasets/B/Image_109.jpg (109/1000)
# Gambar disimpan: datasets/B/Image_110.jpg (110/1000)
# Gambar disimpan: datasets/B/Image_111.jpg (111/1000)
# Gambar disimpan: datasets/B/Image_112.jpg (112/1000)
# Gambar disimpan: datasets/B/Image_113.jpg (113/1000)
# Gambar disimpan: datasets/B/Image_114.jpg (114/1000)
# Gambar disimpan: datasets/B/Image_115.jpg (115/1000)
# Gambar disimpan: datasets/B/Image_116.jpg (116/1000)
# Gambar disimpan: datasets/B/Image_117.jpg (117/1000)
# Gambar disimpan: datasets/B/Image_118.jpg (118/1000)
# Gambar disimpan: datasets/B/Image_119.jpg (119/1000)
# Gambar disimpan: datasets/B/Image_120.jpg (120/1000)
# Gambar disimpan: datasets/B/Image_121.jpg (121/1000)
# Gambar disimpan: datasets/B/Image_122.jpg (122/1000)
# Gambar disimpan: datasets/B/Image_123.jpg (123/1000)
# Gambar disimpan: datasets/B/Image_124.jpg (124/1000)
# Gambar disimpan: datasets/B/Image_125.jpg (125/1000)
# Gambar disimpan: datasets/B/Image_126.jpg (126/1000)
# Gambar disimpan: datasets/B/Image_127.jpg (127/1000)
# Gambar disimpan: datasets/B/Image_128.jpg (128/1000)
# Gambar disimpan: datasets/B/Image_129.jpg (129/1000)
# Gambar disimpan: datasets/B/Image_130.jpg (130/1000)
# Gambar disimpan: datasets/B/Image_131.jpg (131/1000)
# Gambar disimpan: datasets/B/Image_132.jpg (132/1000)
# Gambar disimpan: datasets/B/Image_133.jpg (133/1000)
# Gambar disimpan: datasets/B/Image_134.jpg (134/1000)
# Gambar disimpan: datasets/B/Image_135.jpg (135/1000)
# Gambar disimpan: datasets/B/Image_136.jpg (136/1000)
# Gambar disimpan: datasets/B/Image_137.jpg (137/1000)
# Gambar disimpan: datasets/B/Image_138.jpg (138/1000)
# Gambar disimpan: datasets/B/Image_139.jpg (139/1000)
# Gambar disimpan: datasets/B/Image_140.jpg (140/1000)
# Gambar disimpan: datasets/B/Image_141.jpg (141/1000)
# Gambar disimpan: datasets/B/Image_142.jpg (142/1000)
# Gambar disimpan: datasets/B/Image_143.jpg (143/1000)
# Gambar disimpan: datasets/B/Image_144.jpg (144/1000)
# Gambar disimpan: datasets/B/Image_145.jpg (145/1000)
# Gambar disimpan: datasets/B/Image_146.jpg (146/1000)
# Gambar disimpan: datasets/B/Image_147.jpg (147/1000)
# Gambar disimpan: datasets/B/Image_148.jpg (148/1000)
# Gambar disimpan: datasets/B/Image_149.jpg (149/1000)
# Gambar disimpan: datasets/B/Image_150.jpg (150/1000)
# Gambar disimpan: datasets/B/Image_151.jpg (151/1000)
# Gambar disimpan: datasets/B/Image_152.jpg (152/1000)
# Gambar disimpan: datasets/B/Image_153.jpg (153/1000)
# Gambar disimpan: datasets/B/Image_154.jpg (154/1000)
# Gambar disimpan: datasets/B/Image_155.jpg (155/1000)
# Gambar disimpan: datasets/B/Image_156.jpg (156/1000)
# Gambar disimpan: datasets/B/Image_157.jpg (157/1000)
# Gambar disimpan: datasets/B/Image_158.jpg (158/1000)
# Gambar disimpan: datasets/B/Image_159.jpg (159/1000)
# Gambar disimpan: datasets/B/Image_160.jpg (160/1000)
# Gambar disimpan: datasets/B/Image_161.jpg (161/1000)
# Gambar disimpan: datasets/B/Image_162.jpg (162/1000)
# Gambar disimpan: datasets/B/Image_163.jpg (163/1000)
# Gambar disimpan: datasets/B/Image_164.jpg (164/1000)
# Gambar disimpan: datasets/B/Image_165.jpg (165/1000)
# Gambar disimpan: datasets/B/Image_166.jpg (166/1000)
# Gambar disimpan: datasets/B/Image_167.jpg (167/1000)
# Gambar disimpan: datasets/B/Image_168.jpg (168/1000)
# Gambar disimpan: datasets/B/Image_169.jpg (169/1000)
# Gambar disimpan: datasets/B/Image_170.jpg (170/1000)
# Gambar disimpan: datasets/B/Image_171.jpg (171/1000)
# Gambar disimpan: datasets/B/Image_172.jpg (172/1000)
# Gambar disimpan: datasets/B/Image_173.jpg (173/1000)
# Gambar disimpan: datasets/B/Image_174.jpg (174/1000)
# Gambar disimpan: datasets/B/Image_175.jpg (175/1000)
# Gambar disimpan: datasets/B/Image_176.jpg (176/1000)
# Gambar disimpan: datasets/B/Image_177.jpg (177/1000)
# Gambar disimpan: datasets/B/Image_178.jpg (178/1000)
# Gambar disimpan: datasets/B/Image_179.jpg (179/1000)
# Gambar disimpan: datasets/B/Image_180.jpg (180/1000)
# Gambar disimpan: datasets/B/Image_181.jpg (181/1000)
# Gambar disimpan: datasets/B/Image_182.jpg (182/1000)
# Gambar disimpan: datasets/B/Image_183.jpg (183/1000)
# Gambar disimpan: datasets/B/Image_184.jpg (184/1000)
# Gambar disimpan: datasets/B/Image_185.jpg (185/1000)
# Gambar disimpan: datasets/B/Image_186.jpg (186/1000)
# Gambar disimpan: datasets/B/Image_187.jpg (187/1000)
# Gambar disimpan: datasets/B/Image_188.jpg (188/1000)
# Gambar disimpan: datasets/B/Image_189.jpg (189/1000)
# Gambar disimpan: datasets/B/Image_190.jpg (190/1000)
# Gambar disimpan: datasets/B/Image_191.jpg (191/1000)
# Gambar disimpan: datasets/B/Image_192.jpg (192/1000)
# Gambar disimpan: datasets/B/Image_193.jpg (193/1000)
# Gambar disimpan: datasets/B/Image_194.jpg (194/1000)
# Gambar disimpan: datasets/B/Image_195.jpg (195/1000)
# Gambar disimpan: datasets/B/Image_196.jpg (196/1000)
# Gambar disimpan: datasets/B/Image_197.jpg (197/1000)
# Gambar disimpan: datasets/B/Image_198.jpg (198/1000)
# Gambar disimpan: datasets/B/Image_199.jpg (199/1000)
# Gambar disimpan: datasets/B/Image_200.jpg (200/1000)
# Gambar disimpan: datasets/B/Image_201.jpg (201/1000)
# Gambar disimpan: datasets/B/Image_202.jpg (202/1000)
# Gambar disimpan: datasets/B/Image_203.jpg (203/1000)
# Gambar disimpan: datasets/B/Image_204.jpg (204/1000)
# Gambar disimpan: datasets/B/Image_205.jpg (205/1000)
# Gambar disimpan: datasets/B/Image_206.jpg (206/1000)
# Gambar disimpan: datasets/B/Image_207.jpg (207/1000)
# Gambar disimpan: datasets/B/Image_208.jpg (208/1000)
# Gambar disimpan: datasets/B/Image_209.jpg (209/1000)
# Gambar disimpan: datasets/B/Image_210.jpg (210/1000)
# Gambar disimpan: datasets/B/Image_211.jpg (211/1000)
# Gambar disimpan: datasets/B/Image_212.jpg (212/1000)
# Gambar disimpan: datasets/B/Image_213.jpg (213/1000)
# Gambar disimpan: datasets/B/Image_214.jpg (214/1000)
# Gambar disimpan: datasets/B/Image_215.jpg (215/1000)
# Gambar disimpan: datasets/B/Image_216.jpg (216/1000)
# Gambar disimpan: datasets/B/Image_217.jpg (217/1000)
# Gambar disimpan: datasets/B/Image_218.jpg (218/1000)
# Gambar disimpan: datasets/B/Image_219.jpg (219/1000)
# Gambar disimpan: datasets/B/Image_220.jpg (220/1000)
# Gambar disimpan: datasets/B/Image_221.jpg (221/1000)
# Gambar disimpan: datasets/B/Image_222.jpg (222/1000)
# Gambar disimpan: datasets/B/Image_223.jpg (223/1000)
# Gambar disimpan: datasets/B/Image_224.jpg (224/1000)
# Gambar disimpan: datasets/B/Image_225.jpg (225/1000)
# Gambar disimpan: datasets/B/Image_226.jpg (226/1000)
# Gambar disimpan: datasets/B/Image_227.jpg (227/1000)
# Gambar disimpan: datasets/B/Image_228.jpg (228/1000)
# Gambar disimpan: datasets/B/Image_229.jpg (229/1000)
# Gambar disimpan: datasets/B/Image_230.jpg (230/1000)
# Gambar disimpan: datasets/B/Image_231.jpg (231/1000)
# Gambar disimpan: datasets/B/Image_232.jpg (232/1000)
# Gambar disimpan: datasets/B/Image_233.jpg (233/1000)
# Gambar disimpan: datasets/B/Image_234.jpg (234/1000)
# Gambar disimpan: datasets/B/Image_235.jpg (235/1000)
# Gambar disimpan: datasets/B/Image_236.jpg (236/1000)
# Gambar disimpan: datasets/B/Image_237.jpg (237/1000)
# Gambar disimpan: datasets/B/Image_238.jpg (238/1000)
# Gambar disimpan: datasets/B/Image_239.jpg (239/1000)
# Gambar disimpan: datasets/B/Image_240.jpg (240/1000)
# Gambar disimpan: datasets/B/Image_241.jpg (241/1000)
# Gambar disimpan: datasets/B/Image_242.jpg (242/1000)
# Gambar disimpan: datasets/B/Image_243.jpg (243/1000)
# Gambar disimpan: datasets/B/Image_244.jpg (244/1000)
# Gambar disimpan: datasets/B/Image_245.jpg (245/1000)
# Gambar disimpan: datasets/B/Image_246.jpg (246/1000)
# Gambar disimpan: datasets/B/Image_247.jpg (247/1000)
# Gambar disimpan: datasets/B/Image_248.jpg (248/1000)
# Gambar disimpan: datasets/B/Image_249.jpg (249/1000)
# Gambar disimpan: datasets/B/Image_250.jpg (250/1000)
# Gambar disimpan: datasets/B/Image_251.jpg (251/1000)
# Gambar disimpan: datasets/B/Image_252.jpg (252/1000)
# Gambar disimpan: datasets/B/Image_253.jpg (253/1000)
# Gambar disimpan: datasets/B/Image_254.jpg (254/1000)
# Gambar disimpan: datasets/B/Image_255.jpg (255/1000)
# Gambar disimpan: datasets/B/Image_256.jpg (256/1000)
# Gambar disimpan: datasets/B/Image_257.jpg (257/1000)
# Gambar disimpan: datasets/B/Image_258.jpg (258/1000)
# Gambar disimpan: datasets/B/Image_259.jpg (259/1000)
# Gambar disimpan: datasets/B/Image_260.jpg (260/1000)
# Gambar disimpan: datasets/B/Image_261.jpg (261/1000)
# Gambar disimpan: datasets/B/Image_262.jpg (262/1000)
# Gambar disimpan: datasets/B/Image_263.jpg (263/1000)
# Gambar disimpan: datasets/B/Image_264.jpg (264/1000)
# Gambar disimpan: datasets/B/Image_265.jpg (265/1000)
# Gambar disimpan: datasets/B/Image_266.jpg (266/1000)
# Gambar disimpan: datasets/B/Image_267.jpg (267/1000)
# Gambar disimpan: datasets/B/Image_268.jpg (268/1000)
# Gambar disimpan: datasets/B/Image_269.jpg (269/1000)
# Gambar disimpan: datasets/B/Image_270.jpg (270/1000)
# Gambar disimpan: datasets/B/Image_271.jpg (271/1000)
# Gambar disimpan: datasets/B/Image_272.jpg (272/1000)
# Gambar disimpan: datasets/B/Image_273.jpg (273/1000)
# Gambar disimpan: datasets/B/Image_274.jpg (274/1000)
# Gambar disimpan: datasets/B/Image_275.jpg (275/1000)
# Gambar disimpan: datasets/B/Image_276.jpg (276/1000)
# Gambar disimpan: datasets/B/Image_277.jpg (277/1000)
# Gambar disimpan: datasets/B/Image_278.jpg (278/1000)
# Gambar disimpan: datasets/B/Image_279.jpg (279/1000)
# Gambar disimpan: datasets/B/Image_280.jpg (280/1000)
# Gambar disimpan: datasets/B/Image_281.jpg (281/1000)
# Gambar disimpan: datasets/B/Image_282.jpg (282/1000)
# Gambar disimpan: datasets/B/Image_283.jpg (283/1000)
# Gambar disimpan: datasets/B/Image_284.jpg (284/1000)
# Gambar disimpan: datasets/B/Image_285.jpg (285/1000)
# Gambar disimpan: datasets/B/Image_286.jpg (286/1000)
# Gambar disimpan: datasets/B/Image_287.jpg (287/1000)
# Gambar disimpan: datasets/B/Image_288.jpg (288/1000)
# Gambar disimpan: datasets/B/Image_289.jpg (289/1000)
# Gambar disimpan: datasets/B/Image_290.jpg (290/1000)
# Gambar disimpan: datasets/B/Image_291.jpg (291/1000)
# Gambar disimpan: datasets/B/Image_292.jpg (292/1000)
# Gambar disimpan: datasets/B/Image_293.jpg (293/1000)
# Gambar disimpan: datasets/B/Image_294.jpg (294/1000)
# Gambar disimpan: datasets/B/Image_295.jpg (295/1000)
# Gambar disimpan: datasets/B/Image_296.jpg (296/1000)
# Gambar disimpan: datasets/B/Image_297.jpg (297/1000)
# Gambar disimpan: datasets/B/Image_298.jpg (298/1000)
# Gambar disimpan: datasets/B/Image_299.jpg (299/1000)
# Gambar disimpan: datasets/B/Image_300.jpg (300/1000)
# Gambar disimpan: datasets/B/Image_301.jpg (301/1000)
# Gambar disimpan: datasets/B/Image_302.jpg (302/1000)
# Gambar disimpan: datasets/B/Image_303.jpg (303/1000)
# Gambar disimpan: datasets/B/Image_304.jpg (304/1000)
# Gambar disimpan: datasets/B/Image_305.jpg (305/1000)
# Gambar disimpan: datasets/B/Image_306.jpg (306/1000)
# Gambar disimpan: datasets/B/Image_307.jpg (307/1000)
# Gambar disimpan: datasets/B/Image_308.jpg (308/1000)
# Gambar disimpan: datasets/B/Image_309.jpg (309/1000)
# Gambar disimpan: datasets/B/Image_310.jpg (310/1000)
# Gambar disimpan: datasets/B/Image_311.jpg (311/1000)
# Gambar disimpan: datasets/B/Image_312.jpg (312/1000)
# Gambar disimpan: datasets/B/Image_313.jpg (313/1000)
# Gambar disimpan: datasets/B/Image_314.jpg (314/1000)
# Gambar disimpan: datasets/B/Image_315.jpg (315/1000)
# Gambar disimpan: datasets/B/Image_316.jpg (316/1000)
# Gambar disimpan: datasets/B/Image_317.jpg (317/1000)
# Gambar disimpan: datasets/B/Image_318.jpg (318/1000)
# Gambar disimpan: datasets/B/Image_319.jpg (319/1000)
# Gambar disimpan: datasets/B/Image_320.jpg (320/1000)
# Gambar disimpan: datasets/B/Image_321.jpg (321/1000)
# Gambar disimpan: datasets/B/Image_322.jpg (322/1000)
# Gambar disimpan: datasets/B/Image_323.jpg (323/1000)
# Gambar disimpan: datasets/B/Image_324.jpg (324/1000)
# Gambar disimpan: datasets/B/Image_325.jpg (325/1000)
# Gambar disimpan: datasets/B/Image_326.jpg (326/1000)
# Gambar disimpan: datasets/B/Image_327.jpg (327/1000)
# Gambar disimpan: datasets/B/Image_328.jpg (328/1000)
# Gambar disimpan: datasets/B/Image_329.jpg (329/1000)
# Gambar disimpan: datasets/B/Image_330.jpg (330/1000)
# Gambar disimpan: datasets/B/Image_331.jpg (331/1000)
# Gambar disimpan: datasets/B/Image_332.jpg (332/1000)
# Gambar disimpan: datasets/B/Image_333.jpg (333/1000)
# Gambar disimpan: datasets/B/Image_334.jpg (334/1000)
# Gambar disimpan: datasets/B/Image_335.jpg (335/1000)
# Gambar disimpan: datasets/B/Image_336.jpg (336/1000)
# Gambar disimpan: datasets/B/Image_337.jpg (337/1000)
# Gambar disimpan: datasets/B/Image_338.jpg (338/1000)
# Gambar disimpan: datasets/B/Image_339.jpg (339/1000)
# Gambar disimpan: datasets/B/Image_340.jpg (340/1000)
# Gambar disimpan: datasets/B/Image_341.jpg (341/1000)
# Gambar disimpan: datasets/B/Image_342.jpg (342/1000)
# Gambar disimpan: datasets/B/Image_343.jpg (343/1000)
# Gambar disimpan: datasets/B/Image_344.jpg (344/1000)
# Gambar disimpan: datasets/B/Image_345.jpg (345/1000)
# Gambar disimpan: datasets/B/Image_346.jpg (346/1000)
# Gambar disimpan: datasets/B/Image_347.jpg (347/1000)
# Gambar disimpan: datasets/B/Image_348.jpg (348/1000)
# Gambar disimpan: datasets/B/Image_349.jpg (349/1000)
# Gambar disimpan: datasets/B/Image_350.jpg (350/1000)
# Gambar disimpan: datasets/B/Image_351.jpg (351/1000)
# Gambar disimpan: datasets/B/Image_352.jpg (352/1000)
# Gambar disimpan: datasets/B/Image_353.jpg (353/1000)
# Gambar disimpan: datasets/B/Image_354.jpg (354/1000)
# Gambar disimpan: datasets/B/Image_355.jpg (355/1000)
# Gambar disimpan: datasets/B/Image_356.jpg (356/1000)
# Gambar disimpan: datasets/B/Image_357.jpg (357/1000)
# Gambar disimpan: datasets/B/Image_358.jpg (358/1000)
# Gambar disimpan: datasets/B/Image_359.jpg (359/1000)
# Gambar disimpan: datasets/B/Image_360.jpg (360/1000)
# Gambar disimpan: datasets/B/Image_361.jpg (361/1000)
# Gambar disimpan: datasets/B/Image_362.jpg (362/1000)
# Gambar disimpan: datasets/B/Image_363.jpg (363/1000)
# Gambar disimpan: datasets/B/Image_364.jpg (364/1000)
# Gambar disimpan: datasets/B/Image_365.jpg (365/1000)
# Gambar disimpan: datasets/B/Image_366.jpg (366/1000)
# Gambar disimpan: datasets/B/Image_367.jpg (367/1000)
# Gambar disimpan: datasets/B/Image_368.jpg (368/1000)
# Gambar disimpan: datasets/B/Image_369.jpg (369/1000)
# Gambar disimpan: datasets/B/Image_370.jpg (370/1000)
# Gambar disimpan: datasets/B/Image_371.jpg (371/1000)
# Gambar disimpan: datasets/B/Image_372.jpg (372/1000)
# Gambar disimpan: datasets/B/Image_373.jpg (373/1000)
# Gambar disimpan: datasets/B/Image_374.jpg (374/1000)
# Gambar disimpan: datasets/B/Image_375.jpg (375/1000)
# Gambar disimpan: datasets/B/Image_376.jpg (376/1000)
# Gambar disimpan: datasets/B/Image_377.jpg (377/1000)
# Gambar disimpan: datasets/B/Image_378.jpg (378/1000)
# Gambar disimpan: datasets/B/Image_379.jpg (379/1000)
# Gambar disimpan: datasets/B/Image_380.jpg (380/1000)
# Gambar disimpan: datasets/B/Image_381.jpg (381/1000)
# Gambar disimpan: datasets/B/Image_382.jpg (382/1000)
# Gambar disimpan: datasets/B/Image_383.jpg (383/1000)
# Gambar disimpan: datasets/B/Image_384.jpg (384/1000)
# Gambar disimpan: datasets/B/Image_385.jpg (385/1000)
# Gambar disimpan: datasets/B/Image_386.jpg (386/1000)
# Gambar disimpan: datasets/B/Image_387.jpg (387/1000)
# Gambar disimpan: datasets/B/Image_388.jpg (388/1000)
# Gambar disimpan: datasets/B/Image_389.jpg (389/1000)
# Gambar disimpan: datasets/B/Image_390.jpg (390/1000)
# Gambar disimpan: datasets/B/Image_391.jpg (391/1000)
# Gambar disimpan: datasets/B/Image_392.jpg (392/1000)
# Gambar disimpan: datasets/B/Image_393.jpg (393/1000)
# Gambar disimpan: datasets/B/Image_394.jpg (394/1000)
# Gambar disimpan: datasets/B/Image_395.jpg (395/1000)
# Gambar disimpan: datasets/B/Image_396.jpg (396/1000)
# Gambar disimpan: datasets/B/Image_397.jpg (397/1000)
# Gambar disimpan: datasets/B/Image_398.jpg (398/1000)
# Gambar disimpan: datasets/B/Image_399.jpg (399/1000)
# Gambar disimpan: datasets/B/Image_400.jpg (400/1000)
# Gambar disimpan: datasets/B/Image_401.jpg (401/1000)
# Gambar disimpan: datasets/B/Image_402.jpg (402/1000)
# Gambar disimpan: datasets/B/Image_403.jpg (403/1000)
# Gambar disimpan: datasets/B/Image_404.jpg (404/1000)
# Gambar disimpan: datasets/B/Image_405.jpg (405/1000)
# Gambar disimpan: datasets/B/Image_406.jpg (406/1000)
# Gambar disimpan: datasets/B/Image_407.jpg (407/1000)
# Gambar disimpan: datasets/B/Image_408.jpg (408/1000)
# Gambar disimpan: datasets/B/Image_409.jpg (409/1000)
# Gambar disimpan: datasets/B/Image_410.jpg (410/1000)
# Gambar disimpan: datasets/B/Image_411.jpg (411/1000)
# Gambar disimpan: datasets/B/Image_412.jpg (412/1000)
# Gambar disimpan: datasets/B/Image_413.jpg (413/1000)
# Gambar disimpan: datasets/B/Image_414.jpg (414/1000)
# Gambar disimpan: datasets/B/Image_415.jpg (415/1000)
# Gambar disimpan: datasets/B/Image_416.jpg (416/1000)
# Gambar disimpan: datasets/B/Image_417.jpg (417/1000)
# Gambar disimpan: datasets/B/Image_418.jpg (418/1000)
# Gambar disimpan: datasets/B/Image_419.jpg (419/1000)
# Gambar disimpan: datasets/B/Image_420.jpg (420/1000)
# Gambar disimpan: datasets/B/Image_421.jpg (421/1000)
# Gambar disimpan: datasets/B/Image_422.jpg (422/1000)
# Gambar disimpan: datasets/B/Image_423.jpg (423/1000)
# Gambar disimpan: datasets/B/Image_424.jpg (424/1000)
# Gambar disimpan: datasets/B/Image_425.jpg (425/1000)
# Gambar disimpan: datasets/B/Image_426.jpg (426/1000)
# Gambar disimpan: datasets/B/Image_427.jpg (427/1000)
# Gambar disimpan: datasets/B/Image_428.jpg (428/1000)
# Gambar disimpan: datasets/B/Image_429.jpg (429/1000)
# Gambar disimpan: datasets/B/Image_430.jpg (430/1000)
# Gambar disimpan: datasets/B/Image_431.jpg (431/1000)
# Gambar disimpan: datasets/B/Image_432.jpg (432/1000)
# Gambar disimpan: datasets/B/Image_433.jpg (433/1000)
# Gambar disimpan: datasets/B/Image_434.jpg (434/1000)
# Gambar disimpan: datasets/B/Image_435.jpg (435/1000)
# Gambar disimpan: datasets/B/Image_436.jpg (436/1000)
# Gambar disimpan: datasets/B/Image_437.jpg (437/1000)
# Gambar disimpan: datasets/B/Image_438.jpg (438/1000)
# Gambar disimpan: datasets/B/Image_439.jpg (439/1000)
# Gambar disimpan: datasets/B/Image_440.jpg (440/1000)
# Gambar disimpan: datasets/B/Image_441.jpg (441/1000)
# Gambar disimpan: datasets/B/Image_442.jpg (442/1000)
# Gambar disimpan: datasets/B/Image_443.jpg (443/1000)
# Gambar disimpan: datasets/B/Image_444.jpg (444/1000)
# Gambar disimpan: datasets/B/Image_445.jpg (445/1000)
# Gambar disimpan: datasets/B/Image_446.jpg (446/1000)
# Gambar disimpan: datasets/B/Image_447.jpg (447/1000)
# Gambar disimpan: datasets/B/Image_448.jpg (448/1000)
# Gambar disimpan: datasets/B/Image_449.jpg (449/1000)
# Gambar disimpan: datasets/B/Image_450.jpg (450/1000)
# Gambar disimpan: datasets/B/Image_451.jpg (451/1000)
# Gambar disimpan: datasets/B/Image_452.jpg (452/1000)
# Gambar disimpan: datasets/B/Image_453.jpg (453/1000)
# Gambar disimpan: datasets/B/Image_454.jpg (454/1000)
# Gambar disimpan: datasets/B/Image_455.jpg (455/1000)
# Gambar disimpan: datasets/B/Image_456.jpg (456/1000)
# Gambar disimpan: datasets/B/Image_457.jpg (457/1000)
# Gambar disimpan: datasets/B/Image_458.jpg (458/1000)
# Gambar disimpan: datasets/B/Image_459.jpg (459/1000)
# Gambar disimpan: datasets/B/Image_460.jpg (460/1000)
# Gambar disimpan: datasets/B/Image_461.jpg (461/1000)
# Gambar disimpan: datasets/B/Image_462.jpg (462/1000)
# Gambar disimpan: datasets/B/Image_463.jpg (463/1000)
# Gambar disimpan: datasets/B/Image_464.jpg (464/1000)
# Gambar disimpan: datasets/B/Image_465.jpg (465/1000)
# Gambar disimpan: datasets/B/Image_466.jpg (466/1000)
# Gambar disimpan: datasets/B/Image_467.jpg (467/1000)
# Gambar disimpan: datasets/B/Image_468.jpg (468/1000)
# Gambar disimpan: datasets/B/Image_469.jpg (469/1000)
# Gambar disimpan: datasets/B/Image_470.jpg (470/1000)
# Gambar disimpan: datasets/B/Image_471.jpg (471/1000)
# Gambar disimpan: datasets/B/Image_472.jpg (472/1000)
# Gambar disimpan: datasets/B/Image_473.jpg (473/1000)
# Gambar disimpan: datasets/B/Image_474.jpg (474/1000)
# Gambar disimpan: datasets/B/Image_475.jpg (475/1000)
# Gambar disimpan: datasets/B/Image_476.jpg (476/1000)
# Gambar disimpan: datasets/B/Image_477.jpg (477/1000)
# Gambar disimpan: datasets/B/Image_478.jpg (478/1000)
# Gambar disimpan: datasets/B/Image_479.jpg (479/1000)
# Gambar disimpan: datasets/B/Image_480.jpg (480/1000)
# Gambar disimpan: datasets/B/Image_481.jpg (481/1000)
# Gambar disimpan: datasets/B/Image_482.jpg (482/1000)
# Gambar disimpan: datasets/B/Image_483.jpg (483/1000)
# Gambar disimpan: datasets/B/Image_484.jpg (484/1000)
# Gambar disimpan: datasets/B/Image_485.jpg (485/1000)
# Gambar disimpan: datasets/B/Image_486.jpg (486/1000)
# Gambar disimpan: datasets/B/Image_487.jpg (487/1000)
# Gambar disimpan: datasets/B/Image_488.jpg (488/1000)
# Gambar disimpan: datasets/B/Image_489.jpg (489/1000)
# Gambar disimpan: datasets/B/Image_490.jpg (490/1000)
# Gambar disimpan: datasets/B/Image_491.jpg (491/1000)
# Gambar disimpan: datasets/B/Image_492.jpg (492/1000)
# Gambar disimpan: datasets/B/Image_493.jpg (493/1000)
# Gambar disimpan: datasets/B/Image_494.jpg (494/1000)
# Gambar disimpan: datasets/B/Image_495.jpg (495/1000)
# Gambar disimpan: datasets/B/Image_496.jpg (496/1000)
# Gambar disimpan: datasets/B/Image_497.jpg (497/1000)
# Gambar disimpan: datasets/B/Image_498.jpg (498/1000)
# Gambar disimpan: datasets/B/Image_499.jpg (499/1000)
# Gambar disimpan: datasets/B/Image_500.jpg (500/1000)
# Gambar disimpan: datasets/B/Image_501.jpg (501/1000)
# Gambar disimpan: datasets/B/Image_502.jpg (502/1000)
# Gambar disimpan: datasets/B/Image_503.jpg (503/1000)
# Gambar disimpan: datasets/B/Image_504.jpg (504/1000)
# Gambar disimpan: datasets/B/Image_505.jpg (505/1000)
# Gambar disimpan: datasets/B/Image_506.jpg (506/1000)
# Gambar disimpan: datasets/B/Image_507.jpg (507/1000)
# Gambar disimpan: datasets/B/Image_508.jpg (508/1000)
# Gambar disimpan: datasets/B/Image_509.jpg (509/1000)
# Gambar disimpan: datasets/B/Image_510.jpg (510/1000)
# Gambar disimpan: datasets/B/Image_511.jpg (511/1000)
# Gambar disimpan: datasets/B/Image_512.jpg (512/1000)
# Gambar disimpan: datasets/B/Image_513.jpg (513/1000)
# Gambar disimpan: datasets/B/Image_514.jpg (514/1000)
# Gambar disimpan: datasets/B/Image_515.jpg (515/1000)
# Gambar disimpan: datasets/B/Image_516.jpg (516/1000)
# Gambar disimpan: datasets/B/Image_517.jpg (517/1000)
# Gambar disimpan: datasets/B/Image_518.jpg (518/1000)
# Gambar disimpan: datasets/B/Image_519.jpg (519/1000)
# Gambar disimpan: datasets/B/Image_520.jpg (520/1000)
# Gambar disimpan: datasets/B/Image_521.jpg (521/1000)
# Gambar disimpan: datasets/B/Image_522.jpg (522/1000)
# Gambar disimpan: datasets/B/Image_523.jpg (523/1000)
# Gambar disimpan: datasets/B/Image_524.jpg (524/1000)
# Gambar disimpan: datasets/B/Image_525.jpg (525/1000)
# Gambar disimpan: datasets/B/Image_526.jpg (526/1000)
# Gambar disimpan: datasets/B/Image_527.jpg (527/1000)
# Gambar disimpan: datasets/B/Image_528.jpg (528/1000)
# Gambar disimpan: datasets/B/Image_529.jpg (529/1000)
# Gambar disimpan: datasets/B/Image_530.jpg (530/1000)
# Gambar disimpan: datasets/B/Image_531.jpg (531/1000)
# Gambar disimpan: datasets/B/Image_532.jpg (532/1000)
# Gambar disimpan: datasets/B/Image_533.jpg (533/1000)
# Gambar disimpan: datasets/B/Image_534.jpg (534/1000)
# Gambar disimpan: datasets/B/Image_535.jpg (535/1000)
# Gambar disimpan: datasets/B/Image_536.jpg (536/1000)
# Gambar disimpan: datasets/B/Image_537.jpg (537/1000)
# Gambar disimpan: datasets/B/Image_538.jpg (538/1000)
# Gambar disimpan: datasets/B/Image_539.jpg (539/1000)
# Gambar disimpan: datasets/B/Image_540.jpg (540/1000)
# Gambar disimpan: datasets/B/Image_541.jpg (541/1000)
# Gambar disimpan: datasets/B/Image_542.jpg (542/1000)
# Gambar disimpan: datasets/B/Image_543.jpg (543/1000)
# Gambar disimpan: datasets/B/Image_544.jpg (544/1000)
# Gambar disimpan: datasets/B/Image_545.jpg (545/1000)
# Gambar disimpan: datasets/B/Image_546.jpg (546/1000)
# Gambar disimpan: datasets/B/Image_547.jpg (547/1000)
# Gambar disimpan: datasets/B/Image_548.jpg (548/1000)
# Gambar disimpan: datasets/B/Image_549.jpg (549/1000)
# Gambar disimpan: datasets/B/Image_550.jpg (550/1000)
# Gambar disimpan: datasets/B/Image_551.jpg (551/1000)
# Gambar disimpan: datasets/B/Image_552.jpg (552/1000)
# Gambar disimpan: datasets/B/Image_553.jpg (553/1000)
# Gambar disimpan: datasets/B/Image_554.jpg (554/1000)
# Gambar disimpan: datasets/B/Image_555.jpg (555/1000)
# Gambar disimpan: datasets/B/Image_556.jpg (556/1000)
# Gambar disimpan: datasets/B/Image_557.jpg (557/1000)
# Gambar disimpan: datasets/B/Image_558.jpg (558/1000)
# Gambar disimpan: datasets/B/Image_559.jpg (559/1000)
# Gambar disimpan: datasets/B/Image_560.jpg (560/1000)
# Gambar disimpan: datasets/B/Image_561.jpg (561/1000)
# Gambar disimpan: datasets/B/Image_562.jpg (562/1000)
# Gambar disimpan: datasets/B/Image_563.jpg (563/1000)
# Gambar disimpan: datasets/B/Image_564.jpg (564/1000)
# Gambar disimpan: datasets/B/Image_565.jpg (565/1000)
# Gambar disimpan: datasets/B/Image_566.jpg (566/1000)
# Gambar disimpan: datasets/B/Image_567.jpg (567/1000)
# Gambar disimpan: datasets/B/Image_568.jpg (568/1000)
# Gambar disimpan: datasets/B/Image_569.jpg (569/1000)
# Gambar disimpan: datasets/B/Image_570.jpg (570/1000)
# Gambar disimpan: datasets/B/Image_571.jpg (571/1000)
# Gambar disimpan: datasets/B/Image_572.jpg (572/1000)
# Gambar disimpan: datasets/B/Image_573.jpg (573/1000)
# Gambar disimpan: datasets/B/Image_574.jpg (574/1000)
# Gambar disimpan: datasets/B/Image_575.jpg (575/1000)
# Gambar disimpan: datasets/B/Image_576.jpg (576/1000)
# Gambar disimpan: datasets/B/Image_577.jpg (577/1000)
# Gambar disimpan: datasets/B/Image_578.jpg (578/1000)
# Gambar disimpan: datasets/B/Image_579.jpg (579/1000)
# Gambar disimpan: datasets/B/Image_580.jpg (580/1000)
# Gambar disimpan: datasets/B/Image_581.jpg (581/1000)
# Gambar disimpan: datasets/B/Image_582.jpg (582/1000)
# Gambar disimpan: datasets/B/Image_583.jpg (583/1000)
# Gambar disimpan: datasets/B/Image_584.jpg (584/1000)
# Gambar disimpan: datasets/B/Image_585.jpg (585/1000)
# Gambar disimpan: datasets/B/Image_586.jpg (586/1000)
# Gambar disimpan: datasets/B/Image_587.jpg (587/1000)
# Gambar disimpan: datasets/B/Image_588.jpg (588/1000)
# Gambar disimpan: datasets/B/Image_589.jpg (589/1000)
# Gambar disimpan: datasets/B/Image_590.jpg (590/1000)
# Gambar disimpan: datasets/B/Image_591.jpg (591/1000)
# Gambar disimpan: datasets/B/Image_592.jpg (592/1000)
# Gambar disimpan: datasets/B/Image_593.jpg (593/1000)
# Gambar disimpan: datasets/B/Image_594.jpg (594/1000)
# Gambar disimpan: datasets/B/Image_595.jpg (595/1000)
# Gambar disimpan: datasets/B/Image_596.jpg (596/1000)
# Gambar disimpan: datasets/B/Image_597.jpg (597/1000)
# Gambar disimpan: datasets/B/Image_598.jpg (598/1000)
# Gambar disimpan: datasets/B/Image_599.jpg (599/1000)
# Gambar disimpan: datasets/B/Image_600.jpg (600/1000)
# Gambar disimpan: datasets/B/Image_601.jpg (601/1000)
# Gambar disimpan: datasets/B/Image_602.jpg (602/1000)
# Gambar disimpan: datasets/B/Image_603.jpg (603/1000)
# Gambar disimpan: datasets/B/Image_604.jpg (604/1000)
# Gambar disimpan: datasets/B/Image_605.jpg (605/1000)
# Gambar disimpan: datasets/B/Image_606.jpg (606/1000)
# Gambar disimpan: datasets/B/Image_607.jpg (607/1000)
# Gambar disimpan: datasets/B/Image_608.jpg (608/1000)
# Gambar disimpan: datasets/B/Image_609.jpg (609/1000)
# Gambar disimpan: datasets/B/Image_610.jpg (610/1000)
# Gambar disimpan: datasets/B/Image_611.jpg (611/1000)
# Gambar disimpan: datasets/B/Image_612.jpg (612/1000)
# Gambar disimpan: datasets/B/Image_613.jpg (613/1000)
# Gambar disimpan: datasets/B/Image_614.jpg (614/1000)
# Gambar disimpan: datasets/B/Image_615.jpg (615/1000)
# Gambar disimpan: datasets/B/Image_616.jpg (616/1000)
# Gambar disimpan: datasets/B/Image_617.jpg (617/1000)
# Gambar disimpan: datasets/B/Image_618.jpg (618/1000)
# Gambar disimpan: datasets/B/Image_619.jpg (619/1000)
# Gambar disimpan: datasets/B/Image_620.jpg (620/1000)
# Gambar disimpan: datasets/B/Image_621.jpg (621/1000)
# Gambar disimpan: datasets/B/Image_622.jpg (622/1000)
# Gambar disimpan: datasets/B/Image_623.jpg (623/1000)
# Gambar disimpan: datasets/B/Image_624.jpg (624/1000)
# Gambar disimpan: datasets/B/Image_625.jpg (625/1000)
# Gambar disimpan: datasets/B/Image_626.jpg (626/1000)
# Gambar disimpan: datasets/B/Image_627.jpg (627/1000)
# Gambar disimpan: datasets/B/Image_628.jpg (628/1000)
# Gambar disimpan: datasets/B/Image_629.jpg (629/1000)
# Gambar disimpan: datasets/B/Image_630.jpg (630/1000)
# Gambar disimpan: datasets/B/Image_631.jpg (631/1000)
# Gambar disimpan: datasets/B/Image_632.jpg (632/1000)
# Gambar disimpan: datasets/B/Image_633.jpg (633/1000)
# Gambar disimpan: datasets/B/Image_634.jpg (634/1000)
# Gambar disimpan: datasets/B/Image_635.jpg (635/1000)
# Gambar disimpan: datasets/B/Image_636.jpg (636/1000)
# Gambar disimpan: datasets/B/Image_637.jpg (637/1000)
# Gambar disimpan: datasets/B/Image_638.jpg (638/1000)
# Gambar disimpan: datasets/B/Image_639.jpg (639/1000)
# Gambar disimpan: datasets/B/Image_640.jpg (640/1000)
# Gambar disimpan: datasets/B/Image_641.jpg (641/1000)
# Gambar disimpan: datasets/B/Image_642.jpg (642/1000)
# Gambar disimpan: datasets/B/Image_643.jpg (643/1000)
# Gambar disimpan: datasets/B/Image_644.jpg (644/1000)
# Gambar disimpan: datasets/B/Image_645.jpg (645/1000)
# Gambar disimpan: datasets/B/Image_646.jpg (646/1000)
# Gambar disimpan: datasets/B/Image_647.jpg (647/1000)
# Gambar disimpan: datasets/B/Image_648.jpg (648/1000)
# Gambar disimpan: datasets/B/Image_649.jpg (649/1000)
# Gambar disimpan: datasets/B/Image_650.jpg (650/1000)
# Gambar disimpan: datasets/B/Image_651.jpg (651/1000)
# Gambar disimpan: datasets/B/Image_652.jpg (652/1000)
# Gambar disimpan: datasets/B/Image_653.jpg (653/1000)
# Gambar disimpan: datasets/B/Image_654.jpg (654/1000)
# Gambar disimpan: datasets/B/Image_655.jpg (655/1000)
# Gambar disimpan: datasets/B/Image_656.jpg (656/1000)
# Gambar disimpan: datasets/B/Image_657.jpg (657/1000)
# Gambar disimpan: datasets/B/Image_658.jpg (658/1000)
# Gambar disimpan: datasets/B/Image_659.jpg (659/1000)
# Gambar disimpan: datasets/B/Image_660.jpg (660/1000)
# Gambar disimpan: datasets/B/Image_661.jpg (661/1000)
# Gambar disimpan: datasets/B/Image_662.jpg (662/1000)
# Gambar disimpan: datasets/B/Image_663.jpg (663/1000)
# Gambar disimpan: datasets/B/Image_664.jpg (664/1000)
# Gambar disimpan: datasets/B/Image_665.jpg (665/1000)
# Gambar disimpan: datasets/B/Image_666.jpg (666/1000)
# Gambar disimpan: datasets/B/Image_667.jpg (667/1000)
# Gambar disimpan: datasets/B/Image_668.jpg (668/1000)
# Gambar disimpan: datasets/B/Image_669.jpg (669/1000)
# Gambar disimpan: datasets/B/Image_670.jpg (670/1000)
# Gambar disimpan: datasets/B/Image_671.jpg (671/1000)
# Gambar disimpan: datasets/B/Image_672.jpg (672/1000)
# Gambar disimpan: datasets/B/Image_673.jpg (673/1000)
# Gambar disimpan: datasets/B/Image_674.jpg (674/1000)
# Gambar disimpan: datasets/B/Image_675.jpg (675/1000)
# Gambar disimpan: datasets/B/Image_676.jpg (676/1000)
# Gambar disimpan: datasets/B/Image_677.jpg (677/1000)
# Gambar disimpan: datasets/B/Image_678.jpg (678/1000)
# Gambar disimpan: datasets/B/Image_679.jpg (679/1000)
# Gambar disimpan: datasets/B/Image_680.jpg (680/1000)
# Gambar disimpan: datasets/B/Image_681.jpg (681/1000)
# Gambar disimpan: datasets/B/Image_682.jpg (682/1000)
# Gambar disimpan: datasets/B/Image_683.jpg (683/1000)
# Gambar disimpan: datasets/B/Image_684.jpg (684/1000)
# Gambar disimpan: datasets/B/Image_685.jpg (685/1000)
# Gambar disimpan: datasets/B/Image_686.jpg (686/1000)
# Gambar disimpan: datasets/B/Image_687.jpg (687/1000)
# Gambar disimpan: datasets/B/Image_688.jpg (688/1000)
# Gambar disimpan: datasets/B/Image_689.jpg (689/1000)
# Gambar disimpan: datasets/B/Image_690.jpg (690/1000)
# Gambar disimpan: datasets/B/Image_691.jpg (691/1000)
# Gambar disimpan: datasets/B/Image_692.jpg (692/1000)
# Gambar disimpan: datasets/B/Image_693.jpg (693/1000)
# Gambar disimpan: datasets/B/Image_694.jpg (694/1000)
# Gambar disimpan: datasets/B/Image_695.jpg (695/1000)
# Gambar disimpan: datasets/B/Image_696.jpg (696/1000)
# Gambar disimpan: datasets/B/Image_697.jpg (697/1000)
# Gambar disimpan: datasets/B/Image_698.jpg (698/1000)
# Gambar disimpan: datasets/B/Image_699.jpg (699/1000)
# Gambar disimpan: datasets/B/Image_700.jpg (700/1000)
# Gambar disimpan: datasets/B/Image_701.jpg (701/1000)
# Gambar disimpan: datasets/B/Image_702.jpg (702/1000)
# Gambar disimpan: datasets/B/Image_703.jpg (703/1000)
# Gambar disimpan: datasets/B/Image_704.jpg (704/1000)
# Gambar disimpan: datasets/B/Image_705.jpg (705/1000)
# Gambar disimpan: datasets/B/Image_706.jpg (706/1000)
# Gambar disimpan: datasets/B/Image_707.jpg (707/1000)
# Gambar disimpan: datasets/B/Image_708.jpg (708/1000)
# Gambar disimpan: datasets/B/Image_709.jpg (709/1000)
# Gambar disimpan: datasets/B/Image_710.jpg (710/1000)
# Gambar disimpan: datasets/B/Image_711.jpg (711/1000)
# Gambar disimpan: datasets/B/Image_712.jpg (712/1000)
# Gambar disimpan: datasets/B/Image_713.jpg (713/1000)
# Gambar disimpan: datasets/B/Image_714.jpg (714/1000)
# Gambar disimpan: datasets/B/Image_715.jpg (715/1000)
# Gambar disimpan: datasets/B/Image_716.jpg (716/1000)
# Gambar disimpan: datasets/B/Image_717.jpg (717/1000)
# Gambar disimpan: datasets/B/Image_718.jpg (718/1000)
# Gambar disimpan: datasets/B/Image_719.jpg (719/1000)
# Gambar disimpan: datasets/B/Image_720.jpg (720/1000)
# Gambar disimpan: datasets/B/Image_721.jpg (721/1000)
# Gambar disimpan: datasets/B/Image_722.jpg (722/1000)
# Gambar disimpan: datasets/B/Image_723.jpg (723/1000)
# Gambar disimpan: datasets/B/Image_724.jpg (724/1000)
# Gambar disimpan: datasets/B/Image_725.jpg (725/1000)
# Gambar disimpan: datasets/B/Image_726.jpg (726/1000)
# Gambar disimpan: datasets/B/Image_727.jpg (727/1000)
# Gambar disimpan: datasets/B/Image_728.jpg (728/1000)
# Gambar disimpan: datasets/B/Image_729.jpg (729/1000)
# Gambar disimpan: datasets/B/Image_730.jpg (730/1000)
# Gambar disimpan: datasets/B/Image_731.jpg (731/1000)
# Gambar disimpan: datasets/B/Image_732.jpg (732/1000)
# Gambar disimpan: datasets/B/Image_733.jpg (733/1000)
# Gambar disimpan: datasets/B/Image_734.jpg (734/1000)
# Gambar disimpan: datasets/B/Image_735.jpg (735/1000)
# Gambar disimpan: datasets/B/Image_736.jpg (736/1000)
# Gambar disimpan: datasets/B/Image_737.jpg (737/1000)
# Gambar disimpan: datasets/B/Image_738.jpg (738/1000)
# Gambar disimpan: datasets/B/Image_739.jpg (739/1000)
# Gambar disimpan: datasets/B/Image_740.jpg (740/1000)
# Gambar disimpan: datasets/B/Image_741.jpg (741/1000)
# Gambar disimpan: datasets/B/Image_742.jpg (742/1000)
# Gambar disimpan: datasets/B/Image_743.jpg (743/1000)
# Gambar disimpan: datasets/B/Image_744.jpg (744/1000)
# Gambar disimpan: datasets/B/Image_745.jpg (745/1000)
# Gambar disimpan: datasets/B/Image_746.jpg (746/1000)
# Gambar disimpan: datasets/B/Image_747.jpg (747/1000)
# Gambar disimpan: datasets/B/Image_748.jpg (748/1000)
# Gambar disimpan: datasets/B/Image_749.jpg (749/1000)
# Gambar disimpan: datasets/B/Image_750.jpg (750/1000)
# Gambar disimpan: datasets/B/Image_751.jpg (751/1000)
# Gambar disimpan: datasets/B/Image_752.jpg (752/1000)
# Gambar disimpan: datasets/B/Image_753.jpg (753/1000)
# Gambar disimpan: datasets/B/Image_754.jpg (754/1000)
# Gambar disimpan: datasets/B/Image_755.jpg (755/1000)
# Gambar disimpan: datasets/B/Image_756.jpg (756/1000)
# Gambar disimpan: datasets/B/Image_757.jpg (757/1000)
# Gambar disimpan: datasets/B/Image_758.jpg (758/1000)
# Gambar disimpan: datasets/B/Image_759.jpg (759/1000)
# Gambar disimpan: datasets/B/Image_760.jpg (760/1000)
# Gambar disimpan: datasets/B/Image_761.jpg (761/1000)
# Gambar disimpan: datasets/B/Image_762.jpg (762/1000)
# Gambar disimpan: datasets/B/Image_763.jpg (763/1000)
# Gambar disimpan: datasets/B/Image_764.jpg (764/1000)
# Gambar disimpan: datasets/B/Image_765.jpg (765/1000)
# Gambar disimpan: datasets/B/Image_766.jpg (766/1000)
# Gambar disimpan: datasets/B/Image_767.jpg (767/1000)
# Gambar disimpan: datasets/B/Image_768.jpg (768/1000)
# Gambar disimpan: datasets/B/Image_769.jpg (769/1000)
# Gambar disimpan: datasets/B/Image_770.jpg (770/1000)
# Gambar disimpan: datasets/B/Image_771.jpg (771/1000)
# Gambar disimpan: datasets/B/Image_772.jpg (772/1000)
# Gambar disimpan: datasets/B/Image_773.jpg (773/1000)
# Gambar disimpan: datasets/B/Image_774.jpg (774/1000)
# Gambar disimpan: datasets/B/Image_775.jpg (775/1000)
# Gambar disimpan: datasets/B/Image_776.jpg (776/1000)
# Gambar disimpan: datasets/B/Image_777.jpg (777/1000)
# Gambar disimpan: datasets/B/Image_778.jpg (778/1000)
# Gambar disimpan: datasets/B/Image_779.jpg (779/1000)
# Gambar disimpan: datasets/B/Image_780.jpg (780/1000)
# Gambar disimpan: datasets/B/Image_781.jpg (781/1000)
# Gambar disimpan: datasets/B/Image_782.jpg (782/1000)
# Gambar disimpan: datasets/B/Image_783.jpg (783/1000)
# Gambar disimpan: datasets/B/Image_784.jpg (784/1000)
# Gambar disimpan: datasets/B/Image_785.jpg (785/1000)
# Gambar disimpan: datasets/B/Image_786.jpg (786/1000)
# Gambar disimpan: datasets/B/Image_787.jpg (787/1000)
# Gambar disimpan: datasets/B/Image_788.jpg (788/1000)
# Gambar disimpan: datasets/B/Image_789.jpg (789/1000)
# Gambar disimpan: datasets/B/Image_790.jpg (790/1000)
# Gambar disimpan: datasets/B/Image_791.jpg (791/1000)
# Gambar disimpan: datasets/B/Image_792.jpg (792/1000)
# Gambar disimpan: datasets/B/Image_793.jpg (793/1000)
# Gambar disimpan: datasets/B/Image_794.jpg (794/1000)
# Gambar disimpan: datasets/B/Image_795.jpg (795/1000)
# Gambar disimpan: datasets/B/Image_796.jpg (796/1000)
# Gambar disimpan: datasets/B/Image_797.jpg (797/1000)
# Gambar disimpan: datasets/B/Image_798.jpg (798/1000)
# Gambar disimpan: datasets/B/Image_799.jpg (799/1000)
# Gambar disimpan: datasets/B/Image_800.jpg (800/1000)
# Gambar disimpan: datasets/B/Image_801.jpg (801/1000)
# Gambar disimpan: datasets/B/Image_802.jpg (802/1000)
# Gambar disimpan: datasets/B/Image_803.jpg (803/1000)
# Gambar disimpan: datasets/B/Image_804.jpg (804/1000)
# Gambar disimpan: datasets/B/Image_805.jpg (805/1000)
# Gambar disimpan: datasets/B/Image_806.jpg (806/1000)
# Gambar disimpan: datasets/B/Image_807.jpg (807/1000)
# Gambar disimpan: datasets/B/Image_808.jpg (808/1000)
# Gambar disimpan: datasets/B/Image_809.jpg (809/1000)
# Gambar disimpan: datasets/B/Image_810.jpg (810/1000)
# Gambar disimpan: datasets/B/Image_811.jpg (811/1000)
# Gambar disimpan: datasets/B/Image_812.jpg (812/1000)
# Gambar disimpan: datasets/B/Image_813.jpg (813/1000)
# Gambar disimpan: datasets/B/Image_814.jpg (814/1000)
# Gambar disimpan: datasets/B/Image_815.jpg (815/1000)
# Gambar disimpan: datasets/B/Image_816.jpg (816/1000)
# Gambar disimpan: datasets/B/Image_817.jpg (817/1000)
# Gambar disimpan: datasets/B/Image_818.jpg (818/1000)
# Gambar disimpan: datasets/B/Image_819.jpg (819/1000)
# Gambar disimpan: datasets/B/Image_820.jpg (820/1000)
# Gambar disimpan: datasets/B/Image_821.jpg (821/1000)
# Gambar disimpan: datasets/B/Image_822.jpg (822/1000)
# Gambar disimpan: datasets/B/Image_823.jpg (823/1000)
# Gambar disimpan: datasets/B/Image_824.jpg (824/1000)
# Gambar disimpan: datasets/B/Image_825.jpg (825/1000)
# Gambar disimpan: datasets/B/Image_826.jpg (826/1000)
# Gambar disimpan: datasets/B/Image_827.jpg (827/1000)
# Gambar disimpan: datasets/B/Image_828.jpg (828/1000)
# Gambar disimpan: datasets/B/Image_829.jpg (829/1000)
# Gambar disimpan: datasets/B/Image_830.jpg (830/1000)
# Gambar disimpan: datasets/B/Image_831.jpg (831/1000)
# Gambar disimpan: datasets/B/Image_832.jpg (832/1000)
# Gambar disimpan: datasets/B/Image_833.jpg (833/1000)
# Gambar disimpan: datasets/B/Image_834.jpg (834/1000)
# Gambar disimpan: datasets/B/Image_835.jpg (835/1000)
# Gambar disimpan: datasets/B/Image_836.jpg (836/1000)
# Gambar disimpan: datasets/B/Image_837.jpg (837/1000)
# Gambar disimpan: datasets/B/Image_838.jpg (838/1000)
# Gambar disimpan: datasets/B/Image_839.jpg (839/1000)
# Gambar disimpan: datasets/B/Image_840.jpg (840/1000)
# Gambar disimpan: datasets/B/Image_841.jpg (841/1000)
# Gambar disimpan: datasets/B/Image_842.jpg (842/1000)
# Gambar disimpan: datasets/B/Image_843.jpg (843/1000)
# Gambar disimpan: datasets/B/Image_844.jpg (844/1000)
# Gambar disimpan: datasets/B/Image_845.jpg (845/1000)
# Gambar disimpan: datasets/B/Image_846.jpg (846/1000)
# Gambar disimpan: datasets/B/Image_847.jpg (847/1000)
# Gambar disimpan: datasets/B/Image_848.jpg (848/1000)
# Gambar disimpan: datasets/B/Image_849.jpg (849/1000)
# Gambar disimpan: datasets/B/Image_850.jpg (850/1000)
# Gambar disimpan: datasets/B/Image_851.jpg (851/1000)
# Gambar disimpan: datasets/B/Image_852.jpg (852/1000)
# Gambar disimpan: datasets/B/Image_853.jpg (853/1000)
# Gambar disimpan: datasets/B/Image_854.jpg (854/1000)
# Gambar disimpan: datasets/B/Image_855.jpg (855/1000)
# Gambar disimpan: datasets/B/Image_856.jpg (856/1000)
# Gambar disimpan: datasets/B/Image_857.jpg (857/1000)
# Gambar disimpan: datasets/B/Image_858.jpg (858/1000)
# Gambar disimpan: datasets/B/Image_859.jpg (859/1000)
# Gambar disimpan: datasets/B/Image_860.jpg (860/1000)
# Gambar disimpan: datasets/B/Image_861.jpg (861/1000)
# Gambar disimpan: datasets/B/Image_862.jpg (862/1000)
# Gambar disimpan: datasets/B/Image_863.jpg (863/1000)
# Gambar disimpan: datasets/B/Image_864.jpg (864/1000)
# Gambar disimpan: datasets/B/Image_865.jpg (865/1000)
# Gambar disimpan: datasets/B/Image_866.jpg (866/1000)
# Gambar disimpan: datasets/B/Image_867.jpg (867/1000)
# Gambar disimpan: datasets/B/Image_868.jpg (868/1000)
# Gambar disimpan: datasets/B/Image_869.jpg (869/1000)
# Gambar disimpan: datasets/B/Image_870.jpg (870/1000)
# Gambar disimpan: datasets/B/Image_871.jpg (871/1000)
# Gambar disimpan: datasets/B/Image_872.jpg (872/1000)
# Gambar disimpan: datasets/B/Image_873.jpg (873/1000)
# Gambar disimpan: datasets/B/Image_874.jpg (874/1000)
# Gambar disimpan: datasets/B/Image_875.jpg (875/1000)
# Gambar disimpan: datasets/B/Image_876.jpg (876/1000)
# Gambar disimpan: datasets/B/Image_877.jpg (877/1000)
# Gambar disimpan: datasets/B/Image_878.jpg (878/1000)
# Gambar disimpan: datasets/B/Image_879.jpg (879/1000)
# Gambar disimpan: datasets/B/Image_880.jpg (880/1000)
# Gambar disimpan: datasets/B/Image_881.jpg (881/1000)
# Gambar disimpan: datasets/B/Image_882.jpg (882/1000)
# Gambar disimpan: datasets/B/Image_883.jpg (883/1000)
# Gambar disimpan: datasets/B/Image_884.jpg (884/1000)
# Gambar disimpan: datasets/B/Image_885.jpg (885/1000)
# Gambar disimpan: datasets/B/Image_886.jpg (886/1000)
# Gambar disimpan: datasets/B/Image_887.jpg (887/1000)
# Gambar disimpan: datasets/B/Image_888.jpg (888/1000)
# Gambar disimpan: datasets/B/Image_889.jpg (889/1000)
# Gambar disimpan: datasets/B/Image_890.jpg (890/1000)
# Gambar disimpan: datasets/B/Image_891.jpg (891/1000)
# Gambar disimpan: datasets/B/Image_892.jpg (892/1000)
# Gambar disimpan: datasets/B/Image_893.jpg (893/1000)
# Gambar disimpan: datasets/B/Image_894.jpg (894/1000)
# Gambar disimpan: datasets/B/Image_895.jpg (895/1000)
# Gambar disimpan: datasets/B/Image_896.jpg (896/1000)
# Gambar disimpan: datasets/B/Image_897.jpg (897/1000)
# Gambar disimpan: datasets/B/Image_898.jpg (898/1000)
# Gambar disimpan: datasets/B/Image_899.jpg (899/1000)
# Gambar disimpan: datasets/B/Image_900.jpg (900/1000)
# Gambar disimpan: datasets/B/Image_901.jpg (901/1000)
# Gambar disimpan: datasets/B/Image_902.jpg (902/1000)
# Gambar disimpan: datasets/B/Image_903.jpg (903/1000)
# Gambar disimpan: datasets/B/Image_904.jpg (904/1000)
# Gambar disimpan: datasets/B/Image_905.jpg (905/1000)
# Gambar disimpan: datasets/B/Image_906.jpg (906/1000)
# Gambar disimpan: datasets/B/Image_907.jpg (907/1000)
# Gambar disimpan: datasets/B/Image_908.jpg (908/1000)
# Gambar disimpan: datasets/B/Image_909.jpg (909/1000)
# Gambar disimpan: datasets/B/Image_910.jpg (910/1000)
# Gambar disimpan: datasets/B/Image_911.jpg (911/1000)
# Gambar disimpan: datasets/B/Image_912.jpg (912/1000)
# Gambar disimpan: datasets/B/Image_913.jpg (913/1000)
# Gambar disimpan: datasets/B/Image_914.jpg (914/1000)
# Gambar disimpan: datasets/B/Image_915.jpg (915/1000)
# Gambar disimpan: datasets/B/Image_916.jpg (916/1000)
# Gambar disimpan: datasets/B/Image_917.jpg (917/1000)
# Gambar disimpan: datasets/B/Image_918.jpg (918/1000)
# Gambar disimpan: datasets/B/Image_919.jpg (919/1000)
# Gambar disimpan: datasets/B/Image_920.jpg (920/1000)
# Gambar disimpan: datasets/B/Image_921.jpg (921/1000)
# Gambar disimpan: datasets/B/Image_922.jpg (922/1000)
# Gambar disimpan: datasets/B/Image_923.jpg (923/1000)
# Gambar disimpan: datasets/B/Image_924.jpg (924/1000)
# Gambar disimpan: datasets/B/Image_925.jpg (925/1000)
# Gambar disimpan: datasets/B/Image_926.jpg (926/1000)
# Gambar disimpan: datasets/B/Image_927.jpg (927/1000)
# Gambar disimpan: datasets/B/Image_928.jpg (928/1000)
# Gambar disimpan: datasets/B/Image_929.jpg (929/1000)
# Gambar disimpan: datasets/B/Image_930.jpg (930/1000)
# Gambar disimpan: datasets/B/Image_931.jpg (931/1000)
# Gambar disimpan: datasets/B/Image_932.jpg (932/1000)
# Gambar disimpan: datasets/B/Image_933.jpg (933/1000)
# Gambar disimpan: datasets/B/Image_934.jpg (934/1000)
# Gambar disimpan: datasets/B/Image_935.jpg (935/1000)
# Gambar disimpan: datasets/B/Image_936.jpg (936/1000)
# Gambar disimpan: datasets/B/Image_937.jpg (937/1000)
# Gambar disimpan: datasets/B/Image_938.jpg (938/1000)
# Gambar disimpan: datasets/B/Image_939.jpg (939/1000)
# Gambar disimpan: datasets/B/Image_940.jpg (940/1000)
# Gambar disimpan: datasets/B/Image_941.jpg (941/1000)
# Gambar disimpan: datasets/B/Image_942.jpg (942/1000)
# Gambar disimpan: datasets/B/Image_943.jpg (943/1000)
# Gambar disimpan: datasets/B/Image_944.jpg (944/1000)
# Gambar disimpan: datasets/B/Image_945.jpg (945/1000)
# Gambar disimpan: datasets/B/Image_946.jpg (946/1000)
# Gambar disimpan: datasets/B/Image_947.jpg (947/1000)
# Gambar disimpan: datasets/B/Image_948.jpg (948/1000)
# Gambar disimpan: datasets/B/Image_949.jpg (949/1000)
# Gambar disimpan: datasets/B/Image_950.jpg (950/1000)
# Gambar disimpan: datasets/B/Image_951.jpg (951/1000)
# Gambar disimpan: datasets/B/Image_952.jpg (952/1000)
# Gambar disimpan: datasets/B/Image_953.jpg (953/1000)
# Gambar disimpan: datasets/B/Image_954.jpg (954/1000)
# Gambar disimpan: datasets/B/Image_955.jpg (955/1000)
# Gambar disimpan: datasets/B/Image_956.jpg (956/1000)
# Gambar disimpan: datasets/B/Image_957.jpg (957/1000)
# Gambar disimpan: datasets/B/Image_958.jpg (958/1000)
# Gambar disimpan: datasets/B/Image_959.jpg (959/1000)
# Gambar disimpan: datasets/B/Image_960.jpg (960/1000)
# Gambar disimpan: datasets/B/Image_961.jpg (961/1000)
# Gambar disimpan: datasets/B/Image_962.jpg (962/1000)
# Gambar disimpan: datasets/B/Image_963.jpg (963/1000)
# Gambar disimpan: datasets/B/Image_964.jpg (964/1000)
# Gambar disimpan: datasets/B/Image_965.jpg (965/1000)
# Gambar disimpan: datasets/B/Image_966.jpg (966/1000)
# Gambar disimpan: datasets/B/Image_967.jpg (967/1000)
# Gambar disimpan: datasets/B/Image_968.jpg (968/1000)
# Gambar disimpan: datasets/B/Image_969.jpg (969/1000)
# Gambar disimpan: datasets/B/Image_970.jpg (970/1000)
# Gambar disimpan: datasets/B/Image_971.jpg (971/1000)
# Gambar disimpan: datasets/B/Image_972.jpg (972/1000)
# Gambar disimpan: datasets/B/Image_973.jpg (973/1000)
# Gambar disimpan: datasets/B/Image_974.jpg (974/1000)
# Gambar disimpan: datasets/B/Image_975.jpg (975/1000)
# Gambar disimpan: datasets/B/Image_976.jpg (976/1000)
# Gambar disimpan: datasets/B/Image_977.jpg (977/1000)
# Gambar disimpan: datasets/B/Image_978.jpg (978/1000)
# Gambar disimpan: datasets/B/Image_979.jpg (979/1000)
# Gambar disimpan: datasets/B/Image_980.jpg (980/1000)
# Gambar disimpan: datasets/B/Image_981.jpg (981/1000)
# Gambar disimpan: datasets/B/Image_982.jpg (982/1000)
# Gambar disimpan: datasets/B/Image_983.jpg (983/1000)
# Gambar disimpan: datasets/B/Image_984.jpg (984/1000)
# Gambar disimpan: datasets/B/Image_985.jpg (985/1000)
# Gambar disimpan: datasets/B/Image_986.jpg (986/1000)
# Gambar disimpan: datasets/B/Image_987.jpg (987/1000)
# Gambar disimpan: datasets/B/Image_988.jpg (988/1000)
# Gambar disimpan: datasets/B/Image_989.jpg (989/1000)
# Gambar disimpan: datasets/B/Image_990.jpg (990/1000)
# Gambar disimpan: datasets/B/Image_991.jpg (991/1000)
# Gambar disimpan: datasets/B/Image_992.jpg (992/1000)
# Gambar disimpan: datasets/B/Image_993.jpg (993/1000)
# Gambar disimpan: datasets/B/Image_994.jpg (994/1000)
# Gambar disimpan: datasets/B/Image_995.jpg (995/1000)
# Gambar disimpan: datasets/B/Image_996.jpg (996/1000)
# Gambar disimpan: datasets/B/Image_997.jpg (997/1000)
# Gambar disimpan: datasets/B/Image_998.jpg (998/1000)
# Gambar disimpan: datasets/B/Image_999.jpg (999/1000)
# Gambar disimpan: datasets/B/Image_1000.jpg (1000/1000)
# Sudah mencapai batas maksimal gambar (1000).
